# %% [markdown]
# ## Getting all the data

# %% [markdown]
# ### Modules Import

# %%
from helper import *

# %%
# !pip install plotly
# %matplotlib inline

# %% [markdown]
# ### Kaggle Data

# %%
## This is the main file that has a comprehensive record of most songs from 1921 to 2021 and their audio features. 
## This will be used for labeling and predictions

tracks = pd.read_csv('tracks.csv')

# %%
tracks
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                    artists  \
# 0                6       126903         0                        Uli
# ...

# %%
## takes in str as python code
tracks['id_artists'] = tracks['id_artists'].apply(lambda x: eval(x))

# %%
## Add in Release Year from Release Date
tracks['release_datetime']= pd.to_datetime(tracks['release_date'])
tracks['release_year'] = tracks.release_datetime.dt.year

# %%
tracks['release_year']
# Out:
# 0         1922
# 1         1922
# 2         1922
# 3         1922
# 4         1922
#           ...
# 586667    2020
# 586668    2020
# 586669    2020
# 586670    2021
# 586671    2015
# Name: release_year, Length: 586672, dtype: int64

# %%
tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit          artists                id_artists  \
# 0       126903         0              Uli  [45tIt06XoI0Iio4LBEVpls]
# 1        98200         0  Fernando Pessoa  [14jtPCOoNZwquk5wd9DxrY]
# 2       181640         0  Ignacio Corsini  [5LiOoJbxVSAMkBS2fUm3X2]
# 3       176907         0  Ignacio Corsini  [5LiOoJbxVSAMkBS2fUm3X2]
# 4       163080         0      Dick Haymes  [3BiJGZsyX9sJchTqcSA7Su]
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
tracks.drop(columns=['release_date'], inplace=True)

# %%
tracks
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                    artists  \
# 0                6       126903         0                        Uli
# ...

# %% [markdown]
# ### API Information

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer BQCLIzgdolGJVCycdqsXhAzIwGFK5YAcOKmOjoa3-nfWHtqi_HfLIywnrFuOoyc0NJmLc6W8jZJt609uJryoQAkxrUnawNY0L9AKcUbjxMDkQxp_3YN_iWlwZayi7NBVriWwI7TDHopMQIhgLf6RWj_Hlto4324',
}

# %% [markdown]
# ### Getting all playlists for my user profile

# %%
## I made 50 playlists per mood and I'm grabbing all the playlist IDs here so I can grab the song information for each playlists
## Since there is a limit of 50 playlists per call - I did three separate calls below

params = (
    ('limit', '50'),
)

response = requests.get('https://api.spotify.com/v1/me/playlists', headers=headers, params=params)
playlists = response.json()

# %%
playlist_id = []

for i in range(50):
    playlist_id.append([playlists['items'][i]['name'], playlists['items'][i]['id']])

# %%
## getting second batch of playlists

params = (
    ('limit', '50'),
    ('offset', '50')
)

response_2 = requests.get('https://api.spotify.com/v1/me/playlists', headers=headers, params=params)

# %%
playlist_2 = response_2.json()

# %%
## adding to existing playlist_ids list 

for i in range(50):
    playlist_id.append([playlist_2['items'][i]['name'], playlist_2['items'][i]['id']])

# %%
## getting third batch of playlists

params = (
    ('limit', '50'),
    ('offset', '100')
)

response_3 = requests.get('https://api.spotify.com/v1/me/playlists', headers=headers, params=params)

# %%
playlist_3 = response_3.json()

# %%
## adding to existing playlist_ids list 

for i in range(50):
    playlist_id.append([playlist_3['items'][i]['name'], playlist_3['items'][i]['id']])

# %%
playlist_id

# %%
## filtering to just my mood playlists

mood_playlist_ids = playlist_id
mood_playlist_ids

# %%
## only grab the list of playlist ids

only_playlist_ids = []

for i in range(len(mood_playlist_ids)):
    only_playlist_ids.append(mood_playlist_ids[i][1])

# %%
## list of mood playlists to put into my api calls
only_playlist_ids

# %% [markdown]
# ### Getting Mood Playlist Data

# %%
## Now that I have a list of the playlist IDs, I'm grabbing the track information in each playlist so I can join with my main dataset
## After I join with the main dataset, I'm going to count how many times a song appears in a mood catgory

master_song_list = []

for i in range(len(only_playlist_ids)):
    
    # returns playlist json file
    responses = playlist_calls(only_playlist_ids[i], headers)
    
    #get only the metrics we want
    name = responses['name']

    for i in range(len(responses['tracks']['items'])):
        song_name = responses['tracks']['items'][i]['track']['name']
        song_id = responses['tracks']['items'][i]['track']['id']

        artists = []

        for j in range(len(responses['tracks']['items'][i]['track']['artists'])):
            artists.append(responses['tracks']['items'][i]['track']['artists'][j]['name'])

    # add the playlist, song_id, song_name and artist to a list of lists. each list within the main will be a song
        master_song_list.append([name, song_id, song_name, artists])

#creating dataframe with data. each row is a song
playlist_data = pd.DataFrame(master_song_list,
                             columns=['playlist_name', 'song_id', 'song_name', 'song_artists'])


#saving as csv
playlist_data.to_csv('playlist_data.csv', index=False)

# %%
master_song_list

# %%
playlist_data
# Out:
#       playlist_name                 song_id  \
# 0          angry_50  5cYFwgA5dHoqR3xGnlr9ew
# 1          angry_50  6Ssc4jbDuIwxDp3i60JcT4
# 2          angry_50  5Z0AM9HW78XIyZqF2BPasr
# 3          angry_50  1kJtfldK9F7XmsSiSNlbth
# 4          angry_50  4k80K0b6KZ2QjAYkXON7q6
# ...             ...                     ...
# 13428         sad_1  6edmjzGTcjgml8XzKBFNSh
# 13429         sad_1  7m9OqQk4RVRkw9JJdeAw96
# 13430         sad_1  0a81iNkqAk5vkz7rJJT4L2
# 13431         sad_1  7eJMfftS33KTjuF7lTsMCx
# 13432         sad_1  0xdQb6jQyf69vO41DvLIs7
#
#                                song_name                   song_artists
# 0            I Hope (feat. Charlie Puth)  [Gabby Barrett, Charlie Puth]
# 1            Jason's Song (Gave It Away)                [Ariana Grande]
# 2                                 Bitter               [FLETCHER, Kito]
# 3      Woman (feat. The Dap-Kings Horns)   [Kesha, The Dap-Kings Horns]
# ...

# %%
## create a list of the song ids from all my playlists in order to later get the list of playlists associated with each song

song_list = []

for song_id in playlist_data['song_id']:
    if song_id not in song_list:
        song_list.append(song_id)

# %%
## this is the number of distinct songs in my playlist data
song_list

# %%
## using the song_ids from the list above, we grab the list of playlists per song

song_playlist_list = []

for song_id in song_list: 
    
    subset_data = playlist_data[playlist_data['song_id']==song_id]
    
    playlist_names_list = []
    
    for i in range(len(subset_data['playlist_name'].values)):
        
        playlist_names_list.append(subset_data['playlist_name'].values[i])
    
    song_playlist_list.append([song_id, playlist_names_list])

# %%
song_playlist_list

# %% [markdown]
# ### Appending Missing Songs from Playlist Data to Kaggle Data

# %% [markdown]
# <b> Getting all the missing song IDs <b>

# %% [markdown]
# My original dataset from kaggle were missing some songs that were in my playlist dataset so I have to grab the audio features and song information for those missing songs. The following cells are checking for which songs don't appear in my kaggle dataset so I can grab information about them.

# %%
kaggle_ids = [track for track in tracks['id']]

# %%
## list of ids from kaggle that have playlists

kaggle_ids_playlist = []

for song in song_list:
    if song in kaggle_ids:
        kaggle_ids_playlist.append(song)

# %%
missing_songs = Diff(kaggle_ids_playlist, song_list)

# %%
len(missing_songs)
# Out:
# 4653

# %%
for i,_id in enumerate(missing_songs):
    if type(_id) != str:
        missing_songs.pop(i)

# %% [markdown]
# #### Using missing song IDs to grab the song features and information to add to kaggle dataset
# #### Grab Audio Features of Missing Songs

# %%
import time

missing_song_features = []

## for each song in missing songs list which is the difference between the tracks df and playlist df 
for song in missing_songs:
    
    ## get audio features of each mising song
    params = (('ids', song),)

    response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)

    responses = response.json()['audio_features']

    time.sleep(0.2) 
    
    ## put response in a list for all songs
    missing_song_features.append(responses)

# %%
len(missing_song_features)
# Out:
# 4652

# %%
missing_song_df = pd.DataFrame(columns=['id', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'time_signature'])

# %%
missing_song_df
# Out:
# Empty DataFrame
# Columns: [id, duration_ms, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature]
# Index: []

# %%
missing_song_features[916]
# Out:
# [{'danceability': 0.598,
#   'energy': 0.72,
#   'key': 3,
#   'loudness': -4.426,
#   'mode': 1,
#   'speechiness': 0.0416,
#   'acousticness': 0.215,
#   'instrumentalness': 2.95e-06,
#   'liveness': 0.327,
#   'valence': 0.462,
#   'tempo': 95.025,
#   'type': 'audio_features',
#   'id': '1ApN1loxlt0rzRFc8iETw7',
#   'uri': 'spotify:track:1ApN1loxlt0rzRFc8iETw7',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ApN1loxlt0rzRFc8iETw7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ApN1loxlt0rzRFc8iETw7',
#   'duration_ms': 208128,
#   'time_signature': 4}]

# %%
for i in range(len(missing_song_features)-1):
    
    song_features = missing_song_features[i][0]
    
    missing_song_df = missing_song_df.append(song_features, ignore_index = True)

# %%
missing_song_df
# Out:
#                           id duration_ms  danceability  energy key  loudness  \
# 0     0Svb9UJ4eSBAUcIq7GhdjK      217507         0.517   0.622   1    -3.536
# 1     6FHukarWlx7lSrlaN17OkP      225081         0.709   0.750  10    -4.641
# 2     4fCAOaMs0PYL58OijKp2IS      178512         0.763   0.674   9    -5.146
# 3     5edWHrZTtynGEuSNJHnD3r      137995         0.976   0.440   0   -12.719
# 4     4V0GWXMkzr4dg8jdZF06Bg      289373         0.426   0.748   6    -6.866
# ...                      ...         ...           ...     ...  ..       ...
# 4645  2fOmsaSjCncWDVJ1N8S2TZ      242250         0.643   0.737   9    -3.467
# 4646  0NgzA3THJEEn1q901Mxabt      193506         0.504   0.542   5    -7.171
# 4647  3298yRJKPcCndQdNiTZKIo      203573         0.538   0.127  11   -16.057
# 4648  5C44ht7rPrVh6q8UaDz8ob      232421         0.751   0.752   2    -4.850
# 4649  4uCWi4ySP02NR9DFAcU3zq      229190         0.431   0.548   0    -7.533
#
# ...

# %%
missing_song_df = missing_song_df.replace(np.nan, 0).drop(columns=['analysis_url', 'track_href', 'type', 'uri'])

# %%
missing_song_df
# Out:
#                           id  duration_ms  danceability  energy  key  \
# 0     0Svb9UJ4eSBAUcIq7GhdjK       217507         0.517   0.622    1
# 1     6FHukarWlx7lSrlaN17OkP       225081         0.709   0.750   10
# 2     4fCAOaMs0PYL58OijKp2IS       178512         0.763   0.674    9
# 3     5edWHrZTtynGEuSNJHnD3r       137995         0.976   0.440    0
# 4     4V0GWXMkzr4dg8jdZF06Bg       289373         0.426   0.748    6
# ...                      ...          ...           ...     ...  ...
# 4645  2fOmsaSjCncWDVJ1N8S2TZ       242250         0.643   0.737    9
# 4646  0NgzA3THJEEn1q901Mxabt       193506         0.504   0.542    5
# 4647  3298yRJKPcCndQdNiTZKIo       203573         0.538   0.127   11
# 4648  5C44ht7rPrVh6q8UaDz8ob       232421         0.751   0.752    2
# 4649  4uCWi4ySP02NR9DFAcU3zq       229190         0.431   0.548    0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
missing_song_df.to_csv('missing_song_features.csv')

# %% [markdown]
# #### Grab track information of missing songs (artists, name of track, popularity, explicit, release_date)

# %%
params = (
    ('ids', '7ouMYWpwJ422jRcDASZB7P,4VqPOruhp5EdPBeR92t6lQ,2takcwOaAZWiXQijPHIx7B'),
)

response = requests.get('https://api.spotify.com/v1/tracks', headers=headers, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
missing_song_info = []

for song in missing_songs:
    
    ## get track info of each mising song
    params = (('ids', song),)

    response = requests.get('https://api.spotify.com/v1/tracks', headers=headers, params=params)

    responses = response.json()['tracks'][0]

    time.sleep(0.2) 
    
    ## put response in a list for all songs
    missing_song_info.append(responses)

# %%
## puts track info into a list so we can put it in a dataframe

missing_song_info_list = []

for i in range(len(missing_song_info)):

    missing_song_info_dict = {'id': missing_song_info[i]['id'],
                                  'name': missing_song_info[i]['name'], 
                                   'popularity': missing_song_info[i]['popularity'],
                                   'explicit': missing_song_info[i]['explicit'],
                                   'release_datetime': missing_song_info[i]['album']['release_date']
                                 }
    artist_list = []
    
    for j in range(len(missing_song_info[i]['artists'])):

        artist_list.append(missing_song_info[i]['artists'][j]['name'])

        missing_song_info_dict['artists'] = artist_list

        
    missing_song_info_list.append(missing_song_info_dict)

# %%
missing_song_info_list[500]
# Out:
# {'id': '1Tt4sE4pXi57mTD1GCzsqm',
#  'name': 'Needed Me',
#  'popularity': 1,
#  'explicit': True,
#  'release_datetime': '2016-01-28',
#  'artists': ['Rihanna']}

# %%
missing_song_info_df = pd.DataFrame()

# %%
## putting the missing song info list into empty dataframe

for i in range(len(missing_song_info_list)-1):
    
    song_info = missing_song_info_list[i]
    
    missing_song_info_df = missing_song_info_df.append(song_info, ignore_index = True)

# %%
missing_song_info_df
# Out:
#                            artists  explicit                      id  \
# 0               [Melanie Martinez]       0.0  0Svb9UJ4eSBAUcIq7GhdjK
# 1                     [Alex Aiono]       0.0  6FHukarWlx7lSrlaN17OkP
# 2     [Lauv, Anne-Marie, Ofenbach]       1.0  4fCAOaMs0PYL58OijKp2IS
# 3                        [DaMoNIC]       1.0  5edWHrZTtynGEuSNJHnD3r
# 4               [Ludacris, Monica]       0.0  4V0GWXMkzr4dg8jdZF06Bg
# ...                            ...       ...                     ...
# 4646                  [The Wrecks]       0.0  2fOmsaSjCncWDVJ1N8S2TZ
# 4647              [Brittany Maggs]       1.0  0NgzA3THJEEn1q901Mxabt
# 4648                [Neil Diamond]       0.0  3298yRJKPcCndQdNiTZKIo
# 4649     [Tee Grizzley, Meek Mill]       1.0  5C44ht7rPrVh6q8UaDz8ob
# 4650                [Alex McArtor]       1.0  4uCWi4ySP02NR9DFAcU3zq
#
#                                    name  popularity release_datetime
# 0                      Mrs. Potato Head        31.0       2015-08-14
# ...

# %%
missing_song_table = pd.merge(missing_song_df, missing_song_info_df, left_on = 'id', right_on = 'id', how = 'left')

# %%
## Add in Release Year from Release Date
missing_song_table['release_datetime']= pd.to_datetime(missing_song_table['release_datetime'])
missing_song_table['release_year'] = missing_song_table.release_datetime.dt.year

# %%
missing_song_table
# Out:
#                           id  duration_ms  danceability  energy  key  \
# 0     0Svb9UJ4eSBAUcIq7GhdjK       217507         0.517   0.622    1
# 1     6FHukarWlx7lSrlaN17OkP       225081         0.709   0.750   10
# 2     4fCAOaMs0PYL58OijKp2IS       178512         0.763   0.674    9
# 3     5edWHrZTtynGEuSNJHnD3r       137995         0.976   0.440    0
# 4     4V0GWXMkzr4dg8jdZF06Bg       289373         0.426   0.748    6
# ...                      ...          ...           ...     ...  ...
# 4645  2fOmsaSjCncWDVJ1N8S2TZ       242250         0.643   0.737    9
# 4646  0NgzA3THJEEn1q901Mxabt       193506         0.504   0.542    5
# 4647  3298yRJKPcCndQdNiTZKIo       203573         0.538   0.127   11
# 4648  5C44ht7rPrVh6q8UaDz8ob       232421         0.751   0.752    2
# 4649  4uCWi4ySP02NR9DFAcU3zq       229190         0.431   0.548    0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
## id_artist is not in song_info - adding it back in

missing_song_table['id_artists'] = 0

# %%
missing_song_table
# Out:
#                           id  duration_ms  danceability  energy  key  \
# 0     0Svb9UJ4eSBAUcIq7GhdjK       217507         0.517   0.622    1
# 1     6FHukarWlx7lSrlaN17OkP       225081         0.709   0.750   10
# 2     4fCAOaMs0PYL58OijKp2IS       178512         0.763   0.674    9
# 3     5edWHrZTtynGEuSNJHnD3r       137995         0.976   0.440    0
# 4     4V0GWXMkzr4dg8jdZF06Bg       289373         0.426   0.748    6
# ...                      ...          ...           ...     ...  ...
# 4645  2fOmsaSjCncWDVJ1N8S2TZ       242250         0.643   0.737    9
# 4646  0NgzA3THJEEn1q901Mxabt       193506         0.504   0.542    5
# 4647  3298yRJKPcCndQdNiTZKIo       203573         0.538   0.127   11
# 4648  5C44ht7rPrVh6q8UaDz8ob       232421         0.751   0.752    2
# 4649  4uCWi4ySP02NR9DFAcU3zq       229190         0.431   0.548    0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
missing_song_table = missing_song_table[['id', 
                                        'name', 
                                        'popularity', 
                                        'duration_ms', 
                                        'explicit', 
                                        'artists', 
                                        'id_artists', 
                                        'danceability', 
                                        'energy', 
                                        'key', 
                                        'loudness', 
                                        'mode',
                                        'speechiness', 
                                        'acousticness', 
                                        'instrumentalness', 
                                        'liveness',
                                        'valence', 
                                        'tempo', 
                                        'time_signature', 
                                        'release_datetime',
                                        'release_year']]

# %%
missing_song_table
# Out:
#                           id                               name  popularity  \
# 0     0Svb9UJ4eSBAUcIq7GhdjK                   Mrs. Potato Head        31.0
# 1     6FHukarWlx7lSrlaN17OkP                           Question        41.0
# 2     4fCAOaMs0PYL58OijKp2IS  fuck, i’m lonely - Ofenbach Remix         0.0
# 3     5edWHrZTtynGEuSNJHnD3r                              TURNT        27.0
# 4     4V0GWXMkzr4dg8jdZF06Bg                        Ocean Skies         0.0
# ...                      ...                                ...         ...
# 4645  2fOmsaSjCncWDVJ1N8S2TZ                      Favorite Liar         0.0
# 4646  0NgzA3THJEEn1q901Mxabt                            Reasons        26.0
# 4647  3298yRJKPcCndQdNiTZKIo                     Sweet Caroline         0.0
# 4648  5C44ht7rPrVh6q8UaDz8ob             Beef (feat. Meek Mill)        53.0
# 4649  4uCWi4ySP02NR9DFAcU3zq                          Wasteland        37.0
#
# ...

# %% [markdown]
# ### Adding the Kaggle and Missing Data together

# %% [markdown]
# Now that I have the audio features of the missing songs, I can add it to the kaggle dataset to make the main dataset more comprehensive

# %%
tracks = tracks.append(missing_song_table, ignore_index = True)

# %%
tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve         6.0
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista         0.0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado         0.0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado         0.0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening         0.0
#
#    duration_ms  explicit          artists                id_artists  \
# 0       126903       0.0              Uli  [45tIt06XoI0Iio4LBEVpls]
# 1        98200       0.0  Fernando Pessoa  [14jtPCOoNZwquk5wd9DxrY]
# 2       181640       0.0  Ignacio Corsini  [5LiOoJbxVSAMkBS2fUm3X2]
# 3       176907       0.0  Ignacio Corsini  [5LiOoJbxVSAMkBS2fUm3X2]
# 4       163080       0.0      Dick Haymes  [3BiJGZsyX9sJchTqcSA7Su]
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %% [markdown]
# ### Merging the two datasets together

# %%
song_playlist_df = pd.DataFrame(song_playlist_list, columns = ['song_id', 'playlist_names'])

# %%
song_playlist_df
# Out:
#                      song_id  \
# 0     5cYFwgA5dHoqR3xGnlr9ew
# 1     6Ssc4jbDuIwxDp3i60JcT4
# 2     5Z0AM9HW78XIyZqF2BPasr
# 3     1kJtfldK9F7XmsSiSNlbth
# 4     4k80K0b6KZ2QjAYkXON7q6
# ...                      ...
# 8614  0DsqL82JobsDrMvpMpioSX
# 8615  3PEwQ1uaMwg0ehoTeVm7Yq
# 8616  6edmjzGTcjgml8XzKBFNSh
# 8617  0a81iNkqAk5vkz7rJJT4L2
# 8618  0xdQb6jQyf69vO41DvLIs7
#
#                                                             playlist_names
# 0                                                     [angry_50, angry_36]
# 1                                                     [angry_50, angry_36]
# 2                                   [angry_50, angry_36, angry_8, angry_2]
# 3               [angry_50, angry_43, angry_36, angry_24, angry_3, angry_2]
# 4     [angry_50, angry_36, angry_26, angry_12, angry_11, angry_6, angry_2]
# ...                                                                    ...
# 8614                                                               [sad_1]
# ...

# %%
tracks
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 591317  2fOmsaSjCncWDVJ1N8S2TZ                        Favorite Liar
# 591318  0NgzA3THJEEn1q901Mxabt                              Reasons
# 591319  3298yRJKPcCndQdNiTZKIo                       Sweet Caroline
# 591320  5C44ht7rPrVh6q8UaDz8ob               Beef (feat. Meek Mill)
# 591321  4uCWi4ySP02NR9DFAcU3zq                            Wasteland
#
#         popularity  duration_ms  explicit                    artists  \
# 0              6.0       126903       0.0                        Uli
# ...

# %%
final_table = pd.merge(tracks, song_playlist_df, left_on = 'id', right_on = 'song_id', how = 'left')

# %%
final_table['artists'] = final_table['artists'].astype(str)

# %%
## some songs have multiple rows in here with slightly different features. I just decided to remove the duplicates
final_table.drop_duplicates(subset=['name', 'artists'])
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 591317  2fOmsaSjCncWDVJ1N8S2TZ                        Favorite Liar
# 591318  0NgzA3THJEEn1q901Mxabt                              Reasons
# 591319  3298yRJKPcCndQdNiTZKIo                       Sweet Caroline
# 591320  5C44ht7rPrVh6q8UaDz8ob               Beef (feat. Meek Mill)
# 591321  4uCWi4ySP02NR9DFAcU3zq                            Wasteland
#
#         popularity  duration_ms  explicit                        artists  \
# 0              6.0       126903       0.0                            Uli
# ...

# %%
## checking to see which songs have playlists in them to make sure we have all the songs
final_table_w_playlists = [id for id in final_table[pd.notnull(final_table["playlist_names"])]['id']]
len(final_table_w_playlists)
# Out:
# 8616

# %%
final_table.to_csv('final_table.csv')
